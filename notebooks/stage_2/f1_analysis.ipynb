# %%
import pandas as pd

# %%
df = pd.read_csv("../../gp_outputs/tests.csv")
df.head(3)
# Out:
#    Eval Time  \
# 0   0.020506
# 1   0.018151
# 2   0.018021
#
#                                                                                                                                                                             Expression  \
# 0                                                                                                                                                                  column_MDVP_Shimmer
# 1                                                                                                                                                                   column_Shimmer_DDA
# 2  ((((column_MDVP_Fhi_Hz_ + column_Shimmer_APQ3) + (column_MDVP_PPQ - column_MDVP_Fo_Hz_)) - ((column_PPE - column_RPDE) + (column_Shimmer_APQ5 - column_D2))) + column_MDVP_Flo_Hz_)
#
#    F1 Score  Complexity
# 0  0.736519         0.2
# 1  0.736519         0.2
# 2  0.705216         6.2

# %%
df_sorted = df.sort_values(by='F1 Score', ascending=False)
df_sorted.head(50)
# Out:
#      Eval Time  \
# 138   0.020395
# 333   0.019535
# 699   0.017332
# 694   0.018349
# 717   0.018300
# 21    0.017332
# 649   0.017332
# 599   0.017332
# 549   0.017332
# 375   0.024045
# 449   0.017332
# 488   0.018095
# 679   0.018421
# 677   0.018790
# 399   0.017332
# 349   0.017332
# 149   0.017332
# 150   0.020076
# 99    0.017332
# 158   0.021566
# 199   0.017332
# 172   0.021918
# 299   0.017332
# 241   0.018546
# 262   0.019581
# 49    0.017332
# 326   0.018563
# 303   0.019045
# 499   0.017332
# 506   0.018247
# 249   0.017332
# 381   0.017666
# 87    0.018339
# 119   0.018339
# 117   0.018339
# 140   0.018339
# 527   0.018450
# 545   0.018604
# 625   0.018762
# 628   0.018061
# 569   0.018445
# 652   0.018943
# 561   0.018040
# 535   0.017785
# 470   0.018323
# 469   0.018018
# 368   0.018401
# 390   0.023072
# 419   0.018267
# 163   0.019762
#
# ...
