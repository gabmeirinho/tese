# %%
import pandas as pd

# %%
df = pd.read_csv("../../gp_outputs/tests.csv")
df.head(3)
# Out:
#    Eval Time  \
# 0   0.021078
# 1   0.020645
# 2   0.024859
#
#                                                                                                                                               Expression  \
# 0                                                                                                                                    column_MDVP_Shimmer
# 1  (column_MDVP_Fhi_Hz_ + (((column_Shimmer_APQ3 - column_MDVP_RAP) - column_Shimmer_APQ3) + ((column_MDVP_RAP + column_Shimmer_DDA) - column_spread2)))
# 2                                      (column_MDVP_Fo_Hz_ + (((column_MDVP_Fhi_Hz_ + column_PPE) - column_MDVP_Jitter_Abs_) + column_MDVP_Shimmer_dB_))
#
#    F1 Score  Complexity
# 0  0.736519         0.2
# 1  0.717931         4.8
# 2  0.729691         4.2

# %%
df_sorted = df.sort_values(by='F1 Score', ascending=False)
df_sorted.head(50)
# Out:
#      Eval Time  \
# 326   0.018277
# 131   0.022559
# 481   0.018176
# 499   0.018292
# 296   0.019375
# 319   0.019978
# 234   0.021061
# 255   0.018933
# 15    0.018453
# 687   0.018096
# 670   0.018286
# 143   0.021435
# 672   0.018790
# 151   0.020025
# 165   0.018552
# 368   0.018091
# 710   0.018145
# 764   0.018734
# 777   0.018412
# 374   0.018493
# 80    0.018649
# 538   0.018082
# 253   0.018513
# 60    0.017757
# 520   0.019201
# 528   0.019335
# 724   0.018502
# 762   0.018335
# 562   0.018128
# 554   0.018422
# 280   0.019272
# 645   0.018600
# 194   0.019445
# 210   0.017849
# 152   0.019765
# 156   0.018818
# 463   0.018601
# 462   0.018478
# 361   0.018251
# 621   0.017812
# 618   0.018253
# 84    0.018954
# 104   0.017886
# 107   0.019062
# 137   0.022391
# 383   0.018677
# 781   0.018379
# 8     0.018151
# 42    0.018151
# 412   0.019127
#
# ...
