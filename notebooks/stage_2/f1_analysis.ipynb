# %%
import pandas as pd

# %%
df = pd.read_csv("../../gp_outputs/tests.csv")
df.head(3)
# Out:
#    Eval Time  \
# 0   0.028526
# 1   0.024185
# 2   0.021526
#
#                                                                                                                                               Expression  \
# 0                                                                                                                                    column_MDVP:Shimmer
# 1                                                                                                                                     column_Shimmer:DDA
# 2  (column_MDVP:Fhi(Hz) + (((column_Shimmer:APQ3 - column_MDVP:RAP) - column_Shimmer:APQ3) + ((column_MDVP:RAP + column_Shimmer:DDA) - column_spread1)))
#
#    F1 Score  Complexity
# 0  0.788018         0.2
# 1  0.800268         0.2
# 2  0.788018         4.4

# %%
df_sorted = df.sort_values(by='F1 Score', ascending=False)
df_sorted.head(50)
# Out:
#      Eval Time  \
# 142   0.017959
# 89    0.017959
# 121   0.017959
# 119   0.017959
# 23    0.018139
# 561   0.018243
# 490   0.018725
# 562   0.018156
# 557   0.018121
# 487   0.019291
# 508   0.017824
# 34    0.018272
# 36    0.019630
# 43    0.018627
# 553   0.019118
# 545   0.018324
# 535   0.018324
# 536   0.018229
# 491   0.018324
# 489   0.018217
# 452   0.019413
# 76    0.018825
# 427   0.020178
# 413   0.018773
# 430   0.019466
# 442   0.019167
# 63    0.018650
# 473   0.018475
# 482   0.018151
# 460   0.019749
# 44    0.018293
# 531   0.017998
# 576   0.018148
# 566   0.019508
# 1     0.024185
# 233   0.018185
# 234   0.018764
# 228   0.018454
# 160   0.019292
# 152   0.018477
# 210   0.017880
# 8     0.018028
# 591   0.017981
# 586   0.018822
# 580   0.018449
# 192   0.018616
# 182   0.018793
# 171   0.018998
# 463   0.018677
# 50    0.018028
#
# ...
