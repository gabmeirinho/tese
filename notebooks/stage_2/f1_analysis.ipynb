# %%
import pandas as pd

# %%
df = pd.read_csv("../../gp_outputs/tests.csv")
df.head(3)
# Out:
#    Eval Time                                         Expression  F1 Score  \
# 0   0.040989                                column_MDVP_Shimmer  0.747374
# 1   0.036330                                 column_Shimmer_DDA  0.747374
# 2   0.035912  (((column_Shimmer_APQ3 + (column_MDVP_Flo_Hz_ ...  0.747374
#
#    Complexity
# 0         0.2
# 1         0.2
# 2         7.1

# %%
df_sorted = df.sort_values(by='F1 Score', ascending=False)
df_sorted.head(50)
# Out:
#      Eval Time                                         Expression  F1 Score  \
# 83    0.035730            (column_MDVP_Jitter_ - column_MDVP_RAP)  0.774071
# 525   0.035963  (column_Shimmer_DDA + (column_MDVP_Jitter_ - c...  0.771354
# 636   0.037830                  (column_Shimmer_DDA - column_PPE)  0.756311
# 236   0.036841                                    column_MDVP_APQ  0.750092
# 225   0.036841                                    column_MDVP_APQ  0.750092
# 168   0.034267  ((column_MDVP_RAP + ((column_MDVP_Jitter_Abs_ ...  0.750092
# 94    0.036841                                    column_MDVP_APQ  0.750092
# 199   0.035666  ((column_MDVP_Shimmer - column_MDVP_Jitter_) -...  0.750092
# 237   0.035370                                    column_MDVP_APQ  0.750092
# 154   0.035105  ((column_Shimmer_DDA + (column_MDVP_Flo_Hz_ - ...  0.750092
# 258   0.034719                                    column_MDVP_APQ  0.750092
# ...
